# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
seed = 1
batch_size = 64
test_batch_size = 1000
momentum = 0.9
epochs = 20
log_interval = 100
lr = 0.01
save_model = False
num_classes = 10
criterion = nn.CrossEntropyLoss()
torch.backends.cudnn.benchmark=True

# %%
class CNNNet(nn.Module):
    def __init__(self):
        super(CNNNet, self).__init__()
        self.fc_size = 8 * 8 * 256
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout2d(0.2),
            nn.Conv2d(64, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(self.fc_size, 256),
            nn.ReLU(inplace=True),
            nn.Dropout2d(0.2),
            nn.Linear(256, num_classes),
        )
        

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
def train(model, device, train_loader, optimizer, log_interval, epoch, epochs):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {}/{} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, epochs, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).sum().item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
use_cuda =  torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 2, 'pin_memory': True} if use_cuda else {}

torch.manual_seed(seed)


train_dataset=datasets.CIFAR10('./data_c', train=True, download=True,
    transform=transforms.Compose([
        transforms.ToTensor(),
#                       transforms.Normalize((0.1307,), (0.3081,))
                       
                   ]))

test_dataset=datasets.CIFAR10('./data_c', train=False, download=True,
    transform=transforms.Compose([
        transforms.ToTensor(),
#                       transforms.Normalize((0.1307,), (0.3081,))
    ]))

image, label = train_dataset[0]
print(image.size())
print(label)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 32, 32])
# 6

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, shuffle=True, num_workers=2)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=test_batch_size, shuffle=False, num_workers=2)
for images, labels in train_loader:
    print(images.size())
    print(images[0].size())
    print(labels.size())
    
    break
# Out:
# torch.Size([64, 3, 32, 32])
# torch.Size([3, 32, 32])
# torch.Size([64])

# %%
model = CNNNet().to(device)
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=5e-4)

def run():
    for epoch in range(1, epochs + 1):
        train(model, device, train_loader, optimizer, log_interval, epoch, epochs)
        test(model, device, test_loader)

    if (save_model):
        torch.save(model.state_dict(),"cnn.pt")

# %%
# %%time

run()
# Out:
# Train Epoch: 1/20 [0/50000 (0%)]	Loss: 2.302331
# Train Epoch: 1/20 [6400/50000 (13%)]	Loss: 2.110743
# Train Epoch: 1/20 [12800/50000 (26%)]	Loss: 1.963974
# Train Epoch: 1/20 [19200/50000 (38%)]	Loss: 1.656430
# Train Epoch: 1/20 [25600/50000 (51%)]	Loss: 1.734644
# Train Epoch: 1/20 [32000/50000 (64%)]	Loss: 1.521465
# Train Epoch: 1/20 [38400/50000 (77%)]	Loss: 1.405634
# Train Epoch: 1/20 [44800/50000 (90%)]	Loss: 1.441278
#
# Test set: Average loss: 0.0014, Accuracy: 4859/10000 (49%)
#
# Train Epoch: 2/20 [0/50000 (0%)]	Loss: 1.705333
# Train Epoch: 2/20 [6400/50000 (13%)]	Loss: 1.328960
# Train Epoch: 2/20 [12800/50000 (26%)]	Loss: 1.344746
# Train Epoch: 2/20 [19200/50000 (38%)]	Loss: 1.292666
# Train Epoch: 2/20 [25600/50000 (51%)]	Loss: 1.300901
# Train Epoch: 2/20 [32000/50000 (64%)]	Loss: 1.284314
# Train Epoch: 2/20 [38400/50000 (77%)]	Loss: 1.277954
# Train Epoch: 2/20 [44800/50000 (90%)]	Loss: 1.359057
#
# Test set: Average loss: 0.0011, Accuracy: 6096/10000 (61%)
#
# Train Epoch: 3/20 [0/50000 (0%)]	Loss: 1.051738
# Train Epoch: 3/20 [6400/50000 (13%)]	Loss: 1.243563
# Train Epoch: 3/20 [12800/50000 (26%)]	Loss: 1.301103
# Train Epoch: 3/20 [19200/50000 (38%)]	Loss: 1.146654
# Train Epoch: 3/20 [25600/50000 (51%)]	Loss: 0.954942
# Train Epoch: 3/20 [32000/50000 (64%)]	Loss: 1.406277
# Train Epoch: 3/20 [38400/50000 (77%)]	Loss: 1.047511
# Train Epoch: 3/20 [44800/50000 (90%)]	Loss: 1.115618
#
# Test set: Average loss: 0.0010, Accuracy: 6307/10000 (63%)
#
# Train Epoch: 4/20 [0/50000 (0%)]	Loss: 0.958807
# Train Epoch: 4/20 [6400/50000 (13%)]	Loss: 0.912667
# Train Epoch: 4/20 [12800/50000 (26%)]	Loss: 1.053631
# Train Epoch: 4/20 [19200/50000 (38%)]	Loss: 1.087124
# Train Epoch: 4/20 [25600/50000 (51%)]	Loss: 0.941662
# Train Epoch: 4/20 [32000/50000 (64%)]	Loss: 1.069141
# Train Epoch: 4/20 [38400/50000 (77%)]	Loss: 0.979936
# Train Epoch: 4/20 [44800/50000 (90%)]	Loss: 1.195327
#
# Test set: Average loss: 0.0009, Accuracy: 6771/10000 (68%)
#
# Train Epoch: 5/20 [0/50000 (0%)]	Loss: 1.031559
# Train Epoch: 5/20 [6400/50000 (13%)]	Loss: 0.720497
# Train Epoch: 5/20 [12800/50000 (26%)]	Loss: 0.834817
# Train Epoch: 5/20 [19200/50000 (38%)]	Loss: 0.750108
# Train Epoch: 5/20 [25600/50000 (51%)]	Loss: 1.106662
# Train Epoch: 5/20 [32000/50000 (64%)]	Loss: 1.137954
# Train Epoch: 5/20 [38400/50000 (77%)]	Loss: 0.959509
# Train Epoch: 5/20 [44800/50000 (90%)]	Loss: 1.018113
#
# Test set: Average loss: 0.0009, Accuracy: 6927/10000 (69%)
#
# Train Epoch: 6/20 [0/50000 (0%)]	Loss: 1.033285
# Train Epoch: 6/20 [6400/50000 (13%)]	Loss: 0.984534
# Train Epoch: 6/20 [12800/50000 (26%)]	Loss: 0.768350
# Train Epoch: 6/20 [19200/50000 (38%)]	Loss: 0.659496
# Train Epoch: 6/20 [25600/50000 (51%)]	Loss: 0.627753
# Train Epoch: 6/20 [32000/50000 (64%)]	Loss: 0.839124
# Train Epoch: 6/20 [38400/50000 (77%)]	Loss: 1.003751
# Train Epoch: 6/20 [44800/50000 (90%)]	Loss: 0.638695
#
# Test set: Average loss: 0.0009, Accuracy: 6918/10000 (69%)
#
# Train Epoch: 7/20 [0/50000 (0%)]	Loss: 0.873481
# Train Epoch: 7/20 [6400/50000 (13%)]	Loss: 0.779405
# Train Epoch: 7/20 [12800/50000 (26%)]	Loss: 0.828019
# Train Epoch: 7/20 [19200/50000 (38%)]	Loss: 0.651011
# Train Epoch: 7/20 [25600/50000 (51%)]	Loss: 0.713395
# Train Epoch: 7/20 [32000/50000 (64%)]	Loss: 0.776430
# Train Epoch: 7/20 [38400/50000 (77%)]	Loss: 0.877361
# Train Epoch: 7/20 [44800/50000 (90%)]	Loss: 0.740757
#
# Test set: Average loss: 0.0008, Accuracy: 7180/10000 (72%)
#
# Train Epoch: 8/20 [0/50000 (0%)]	Loss: 0.537298
# Train Epoch: 8/20 [6400/50000 (13%)]	Loss: 0.485743
# Train Epoch: 8/20 [12800/50000 (26%)]	Loss: 0.638413
# Train Epoch: 8/20 [19200/50000 (38%)]	Loss: 0.586517
# Train Epoch: 8/20 [25600/50000 (51%)]	Loss: 0.910602
# Train Epoch: 8/20 [32000/50000 (64%)]	Loss: 0.836151
# Train Epoch: 8/20 [38400/50000 (77%)]	Loss: 0.795891
# Train Epoch: 8/20 [44800/50000 (90%)]	Loss: 0.638729
#
# Test set: Average loss: 0.0008, Accuracy: 7215/10000 (72%)
#
# Train Epoch: 9/20 [0/50000 (0%)]	Loss: 0.622280
# Train Epoch: 9/20 [6400/50000 (13%)]	Loss: 0.754342
# Train Epoch: 9/20 [12800/50000 (26%)]	Loss: 0.896875
# Train Epoch: 9/20 [19200/50000 (38%)]	Loss: 0.445371
# Train Epoch: 9/20 [25600/50000 (51%)]	Loss: 0.585444
# Train Epoch: 9/20 [32000/50000 (64%)]	Loss: 0.609666
# Train Epoch: 9/20 [38400/50000 (77%)]	Loss: 0.644976
# Train Epoch: 9/20 [44800/50000 (90%)]	Loss: 0.506812
#
# Test set: Average loss: 0.0008, Accuracy: 7351/10000 (74%)
#
# Train Epoch: 10/20 [0/50000 (0%)]	Loss: 0.370098
# Train Epoch: 10/20 [6400/50000 (13%)]	Loss: 0.438443
# Train Epoch: 10/20 [12800/50000 (26%)]	Loss: 0.637170
# Train Epoch: 10/20 [19200/50000 (38%)]	Loss: 0.742675
# Train Epoch: 10/20 [25600/50000 (51%)]	Loss: 0.644126
# Train Epoch: 10/20 [32000/50000 (64%)]	Loss: 0.427863
# Train Epoch: 10/20 [38400/50000 (77%)]	Loss: 0.500464
# Train Epoch: 10/20 [44800/50000 (90%)]	Loss: 0.575078
#
# Test set: Average loss: 0.0008, Accuracy: 7393/10000 (74%)
#
# Train Epoch: 11/20 [0/50000 (0%)]	Loss: 0.471663
# Train Epoch: 11/20 [6400/50000 (13%)]	Loss: 0.347526
# Train Epoch: 11/20 [12800/50000 (26%)]	Loss: 0.380913
# Train Epoch: 11/20 [19200/50000 (38%)]	Loss: 0.317478
# Train Epoch: 11/20 [25600/50000 (51%)]	Loss: 0.435242
# Train Epoch: 11/20 [32000/50000 (64%)]	Loss: 0.434117
# Train Epoch: 11/20 [38400/50000 (77%)]	Loss: 0.450942
# Train Epoch: 11/20 [44800/50000 (90%)]	Loss: 0.452867
#
# Test set: Average loss: 0.0008, Accuracy: 7387/10000 (74%)
#
# Train Epoch: 12/20 [0/50000 (0%)]	Loss: 0.578591
# Train Epoch: 12/20 [6400/50000 (13%)]	Loss: 0.305620
# Train Epoch: 12/20 [12800/50000 (26%)]	Loss: 0.284483
# Train Epoch: 12/20 [19200/50000 (38%)]	Loss: 0.356186
# Train Epoch: 12/20 [25600/50000 (51%)]	Loss: 0.377810
# Train Epoch: 12/20 [32000/50000 (64%)]	Loss: 0.295344
# Train Epoch: 12/20 [38400/50000 (77%)]	Loss: 0.441154
# Train Epoch: 12/20 [44800/50000 (90%)]	Loss: 0.484915
#
# Test set: Average loss: 0.0008, Accuracy: 7381/10000 (74%)
#
# Train Epoch: 13/20 [0/50000 (0%)]	Loss: 0.376244
# Train Epoch: 13/20 [6400/50000 (13%)]	Loss: 0.277336
# Train Epoch: 13/20 [12800/50000 (26%)]	Loss: 0.330647
# Train Epoch: 13/20 [19200/50000 (38%)]	Loss: 0.304157
# Train Epoch: 13/20 [25600/50000 (51%)]	Loss: 0.318260
# Train Epoch: 13/20 [32000/50000 (64%)]	Loss: 0.468606
# Train Epoch: 13/20 [38400/50000 (77%)]	Loss: 0.279940
# Train Epoch: 13/20 [44800/50000 (90%)]	Loss: 0.421909
#
# Test set: Average loss: 0.0008, Accuracy: 7377/10000 (74%)
#
# Train Epoch: 14/20 [0/50000 (0%)]	Loss: 0.173090
# Train Epoch: 14/20 [6400/50000 (13%)]	Loss: 0.327224
# Train Epoch: 14/20 [12800/50000 (26%)]	Loss: 0.333451
# Train Epoch: 14/20 [19200/50000 (38%)]	Loss: 0.272844
# Train Epoch: 14/20 [25600/50000 (51%)]	Loss: 0.389858
# Train Epoch: 14/20 [32000/50000 (64%)]	Loss: 0.324620
# Train Epoch: 14/20 [38400/50000 (77%)]	Loss: 0.339636
# Train Epoch: 14/20 [44800/50000 (90%)]	Loss: 0.193452
#
# Test set: Average loss: 0.0009, Accuracy: 7329/10000 (73%)
#
# Train Epoch: 15/20 [0/50000 (0%)]	Loss: 0.263320
# Train Epoch: 15/20 [6400/50000 (13%)]	Loss: 0.156245
# Train Epoch: 15/20 [12800/50000 (26%)]	Loss: 0.286434
# Train Epoch: 15/20 [19200/50000 (38%)]	Loss: 0.203357
# Train Epoch: 15/20 [25600/50000 (51%)]	Loss: 0.347962
# Train Epoch: 15/20 [32000/50000 (64%)]	Loss: 0.331082
# Train Epoch: 15/20 [38400/50000 (77%)]	Loss: 0.252858
# Train Epoch: 15/20 [44800/50000 (90%)]	Loss: 0.328533
#
# Test set: Average loss: 0.0009, Accuracy: 7415/10000 (74%)
#
# Train Epoch: 16/20 [0/50000 (0%)]	Loss: 0.165864
# Train Epoch: 16/20 [6400/50000 (13%)]	Loss: 0.176514
# Train Epoch: 16/20 [12800/50000 (26%)]	Loss: 0.249797
# Train Epoch: 16/20 [19200/50000 (38%)]	Loss: 0.201763
# Train Epoch: 16/20 [25600/50000 (51%)]	Loss: 0.227936
# Train Epoch: 16/20 [32000/50000 (64%)]	Loss: 0.369959
# Train Epoch: 16/20 [38400/50000 (77%)]	Loss: 0.198067
# Train Epoch: 16/20 [44800/50000 (90%)]	Loss: 0.341719
#
# Test set: Average loss: 0.0009, Accuracy: 7367/10000 (74%)
#
# Train Epoch: 17/20 [0/50000 (0%)]	Loss: 0.213794
# Train Epoch: 17/20 [6400/50000 (13%)]	Loss: 0.225320
# Train Epoch: 17/20 [12800/50000 (26%)]	Loss: 0.117296
# Train Epoch: 17/20 [19200/50000 (38%)]	Loss: 0.273768
# Train Epoch: 17/20 [25600/50000 (51%)]	Loss: 0.222067
# Train Epoch: 17/20 [32000/50000 (64%)]	Loss: 0.253329
# Train Epoch: 17/20 [38400/50000 (77%)]	Loss: 0.115406
# Train Epoch: 17/20 [44800/50000 (90%)]	Loss: 0.279817
#
# Test set: Average loss: 0.0009, Accuracy: 7370/10000 (74%)
# Train Epoch: 18/20 [0/50000 (0%)]	Loss: 0.232355
# Train Epoch: 18/20 [6400/50000 (13%)]	Loss: 0.182872
# Train Epoch: 18/20 [12800/50000 (26%)]	Loss: 0.252361
# Train Epoch: 18/20 [19200/50000 (38%)]	Loss: 0.182098
# Train Epoch: 18/20 [25600/50000 (51%)]	Loss: 0.118063
# Train Epoch: 18/20 [32000/50000 (64%)]	Loss: 0.087268
# Train Epoch: 18/20 [38400/50000 (77%)]	Loss: 0.135847
# Train Epoch: 18/20 [44800/50000 (90%)]	Loss: 0.168956
#
# Test set: Average loss: 0.0009, Accuracy: 7408/10000 (74%)
#
# Train Epoch: 19/20 [0/50000 (0%)]	Loss: 0.149065
# Train Epoch: 19/20 [6400/50000 (13%)]	Loss: 0.122715
# Train Epoch: 19/20 [12800/50000 (26%)]	Loss: 0.159983
# Train Epoch: 19/20 [19200/50000 (38%)]	Loss: 0.164055
# Train Epoch: 19/20 [25600/50000 (51%)]	Loss: 0.299065
# Train Epoch: 19/20 [32000/50000 (64%)]	Loss: 0.166660
# Train Epoch: 19/20 [38400/50000 (77%)]	Loss: 0.181905
# Train Epoch: 19/20 [44800/50000 (90%)]	Loss: 0.149366
#
# Test set: Average loss: 0.0010, Accuracy: 7364/10000 (74%)
#
# Train Epoch: 20/20 [0/50000 (0%)]	Loss: 0.127873
# Train Epoch: 20/20 [6400/50000 (13%)]	Loss: 0.197254
# Train Epoch: 20/20 [12800/50000 (26%)]	Loss: 0.089122
# Train Epoch: 20/20 [19200/50000 (38%)]	Loss: 0.202006
# Train Epoch: 20/20 [25600/50000 (51%)]	Loss: 0.165839
# Train Epoch: 20/20 [32000/50000 (64%)]	Loss: 0.122440
# Train Epoch: 20/20 [38400/50000 (77%)]	Loss: 0.158311
# Train Epoch: 20/20 [44800/50000 (90%)]	Loss: 0.200937
#
# Test set: Average loss: 0.0009, Accuracy: 7443/10000 (74%)
#
# CPU times: user 2min 5s, sys: 40.8 s, total: 2min 46s
# Wall time: 2min 55s
